# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import re

site = 'https://datawrapper.dwcdn.net/5vPn3/5/'

# %%
response = requests.get(site)
response.status_code
page = response.text

# %%
response = urllib2.urlopen(iframe.attr['src'])

# %%
soup = BeautifulSoup(page, 'html.parser')

# %%
page[:10000]
# Out:
# &#39;&lt;!DOCTYPE html&gt;&lt;html lang=&quot;en&quot;&gt;&lt;head&gt;&lt;meta charset=&quot;UTF-8&quot;&gt;&lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;&gt;&lt;style&gt;@import &quot;https://static.dwcdn.net/css/roboto.css&quot;;body{background:transparent}.chart,body{margin:0;padding:0}.chart{font-family:Roboto,sans-serif;color:#181818;font-size:12px;height:100%}.chart.vis-height-fit{overflow:hidden}.chart a{color:#18a1cd;text-decoration:none}.chart .dw-chart-header{min-height:1px;position:relative;overflow:auto}.chart .dw-chart-header .header-right{position:absolute;right:10px;z-index:20}.chart .dw-chart-header .headline-block{margin:0 0 10px}.chart .dw-chart-header h1{font-weight:700;font-size:22px;color:#000}.chart .dw-chart-header h1,.chart .dw-chart-header p{font-family:Roboto,sans-serif;font-style:normal;text-decoration:none;margin:0}.chart .dw-chart-header p{font-weight:400;font-size:14px;line-height:17px}.chart .dw-chart-header
# ...

# %%
datare = re.compile('Dusty')
li = soup.find(text=datare)

# %%
li
# Out:
# 9390\\\\t73.9%\\\\nOK-04\\\\tTom Cole (R)\\\\tR+20\\\\t84023\\\\t28.4%\\\\t193819\\\\t65.6%\\\\t86357\\\\t32.9%\\\\t175956\\\\t67.1%\\\\nOK-05\\\\tKendra Horn (D)\\\\tR+10\\\\t111394\\\\t39.7%\\\\t149741\\\\t53.3%\\\\t107344\\\\t40.8%\\\\t156035\\\\t59.2%\\\\nOR-01\\\\tSuzanne Bonamici (D)\\\\tD+9\\\\t219420\\\\t55.0%\\\\t132161\\\\t33.1%\\\\t200993\\\\t56.8%\\\\t140462\\\\t39.7%\\\\nOR-02\\\\tGreg Walden (R)\\\\tR+11\\\\t139059\\\\t35.3%\\\\t215711\\\\t54.7%\\\\t139940\\\\t40.1%\\\\t196568\\\\t56.4%\\\\nOR-03\\\\tEarl Blumenauer (D)\\\\tD+24\\\\t282341\\\\t68.4%\\\\t89678\\\\t21.7%\\\\t268004\\\\t71.6%\\\\t91733\\\\t24.5%\\\\nOR-04\\\\tPeter DeFazio (D)\\\\tEVEN\\\\t180872\\\\t44.5%\\\\t180318\\\\t44.4%\\\\t188563\\\\t51.4%\\\\t163931\\\\t44.7%\\\\nOR-05\\\\tKurt Schrader (D)\\\\tEVEN\\\\t180415\\\\t46.4%\\\\t164535\\\\t42.3%\\\\t172986\\\\t50.1%\\\\t161482\\\\t46.8%\\\\nPA-01\\\\tBrian Fitzpatrick (R)\\\\tR+1\\\\t\\\\t49.1%\\\\t\\\\t47.1%\\\\t\\\\t50.3%\\\\t\\\\t48.4%\\\\nPA-02\\\\
# ...

# %%
sc = soup.find_all('script')

# %%
sc[1]
# Out:
# 125897\\t39.3%\\nNY-26\\tBrian Higgins (D)\\tD+11\\t175336\\t57.5%\\t115558\\t37.9%\\t193362\\t63.9%\\t103743\\t34.3%\\nNY-27\\tChris Collins (R)\\tR+11\\t122091\\t35.0%\\t206854\\t59.3%\\t140136\\t42.8%\\t180681\\t55.2%\\nNC-01\\tG.K. Butterfield (D)\\tD+17\\t237020\\t65.9%\\t111804\\t31.1%\\t\\t\\t\\t\\nNC-02\\tGeorge Holding (R)\\tR+7\\t179123\\t44.6%\\t204225\\t50.9%\\t\\t\\t\\t\\nNC-03\\tVACANT (Jones) (R)\\tR+12\\t122550\\t37.0%\\t197447\\t59.6%\\t\\t\\t\\t\\nNC-04\\tDavid Price (D)\\tD+17\\t276030\\t65.7%\\t121938\\t29.0%\\t\\t\\t\\t\\nNC-05\\tVirginia Foxx (R)\\tR+10\\t142373\\t39.2%\\t205321\\t56.6%\\t\\t\\t\\t\\nNC-06\\tMark Walker (R)\\tR+9\\t148687\\t41.0%\\t201390\\t55.6%\\t\\t\\t\\t\\nNC-07\\tDavid Rouzer (R)\\tR+9\\t143255\\t39.6%\\t205699\\t56.9%\\t\\t\\t\\t\\nNC-08\\tRichard Hudson (R)\\tR+8\\t136252\\t40.7%\\t185882\\t55.5%\\t\\t\\t\\t\\nNC-09\\t()\\tR+8\\t147301\\t42.4%\\t185859\\t53.5%\\t\\t\\t\\t\\nNC-10\\tPatrick McHenry (R)\\tR+12\\t128359\\t35.7%\\t217624\\t60
# ...

# %%
print('hi')
# Out:
# hi
